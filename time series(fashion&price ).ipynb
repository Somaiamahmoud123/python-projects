# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

# %%
data=pd.read_csv( r'C:\Users\Allewaa\Desktop\multiTimeline.csv',skiprows=1 )
data
# Out:
#        Month  Fashion: (Worldwide)  price: (Worldwide)  country: (Worldwide)
# 0    2004-01                    12                  25                    17
# 1    2004-02                    13                  23                    17
# 2    2004-03                    13                  23                    17
# 3    2004-04                    12                  23                    18
# 4    2004-05                    12                  23                    18
# ..       ...                   ...                 ...                   ...
# 232  2023-05                    10                  83                    16
# 233  2023-06                    10                  89                    16
# 234  2023-07                     9                  94                    16
# 235  2023-08                     9                  94                    16
# 236  2023-09                     9                  87                    16
#
# [237 rows x 4 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237 entries, 0 to 236
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Month                 237 non-null    object
#  1   Fashion: (Worldwide)  237 non-null    int64
#  2   price: (Worldwide)    237 non-null    int64
#  3   country: (Worldwide)  237 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 7.5+ KB

# %%
data.columns=['Month','Fashion','Price','Country']
data
# Out:
#        Month  Fashion  Price  Country
# 0    2004-01       12     25       17
# 1    2004-02       13     23       17
# 2    2004-03       13     23       17
# 3    2004-04       12     23       18
# 4    2004-05       12     23       18
# ..       ...      ...    ...      ...
# 232  2023-05       10     83       16
# 233  2023-06       10     89       16
# 234  2023-07        9     94       16
# 235  2023-08        9     94       16
# 236  2023-09        9     87       16
#
# [237 rows x 4 columns]

# %%
data['Month'] = pd.to_datetime(data['Month'])
data
# Out:
#          Month  Fashion  Price  Country
# 0   2004-01-01       12     25       17
# 1   2004-02-01       13     23       17
# 2   2004-03-01       13     23       17
# 3   2004-04-01       12     23       18
# 4   2004-05-01       12     23       18
# ..         ...      ...    ...      ...
# 232 2023-05-01       10     83       16
# 233 2023-06-01       10     89       16
# 234 2023-07-01        9     94       16
# 235 2023-08-01        9     94       16
# 236 2023-09-01        9     87       16
#
# [237 rows x 4 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237 entries, 0 to 236
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Month    237 non-null    datetime64[ns]
#  1   Fashion  237 non-null    int64
#  2   Price    237 non-null    int64
#  3   Country  237 non-null    int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 7.5 KB

# %%
data.set_index('Month',inplace=True)

# %%
data.plot(figsize=(20,10))
# Out:
# <Axes: xlabel='Month'>

# %%
data[['Price']].plot(figsize=(20,10))
# Out:
# <Axes: xlabel='Month'>

# %%
data[['Price']].rolling(12).mean().plot()
# Out:
# <Axes: xlabel='Month'>

# %%
pd.concat([data[['Price']].rolling(12).mean(),data[['Fashion']].rolling(12).mean()],axis=1).plot(figsize=(20,10))
# Out:
# <Axes: xlabel='Month'>
